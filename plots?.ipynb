# %%
#Messing around with the TwoBody library 
import astropy.units as u
import numpy as np
import matplotlib.pyplot as plt

from astropy.time import Time
from twobody import KeplerOrbit
from astropy.io import fits
from astropy.time import Time
from thejoker.data import RVData

from astropy.table import Table
from twobody.wrap import cy_rv_from_elements
from twobody.utils import ArrayProcessor

AllAvgSimp  = Table(fits.getdata('/home/cody/Binary Search/AllAvgSimp.fits',1))
AllVisSimp  = Table(fits.getdata('/home/cody/Binary Search/AllVisSimp.fits',1))
foo_samples = Table(fits.getdata('/home/cody/Binary Search/2M00055448-7714368/2M00055448-7714368.fits',1))
# Out:
# /home/cody/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters

# %%
foo_samples
# Out:
# <Table length=836>
#         P                   M0         ...         v0
#      float64             float64       ...      float64
# ------------------ ------------------- ... ------------------
# 158.50974379263414 0.18139114164280754 ... 13.225779764503333
#  36.80752748991876  1.1950436793099777 ...  13.10466621022993
# 109.56632249844021  0.2839871470653444 ...  13.22299050974628
#  158.9495185922919  5.4364402358671375 ... 13.158484085970747
#  143.1880407190473  1.7585017923080186 ...  13.07742621608544
#   67.7783826092549   1.307610976408379 ... 13.156368105043889
# 18.490152028753805   6.146223935067629 ... 13.163062866643088
# 46.972617467513125   5.270899377009071 ... 13.125940007116162
#  47.37366743885466   6.024479571389058 ... 13.145748040913906
#  47.29352592996271   5.441877888255881 ... 13.149073741617869
#                ...                 ... ...                ...
# 124.14300384424301  1.2320870398733796 ... 13.183107920815331
# ...

# %%
#Make a bunch of different plots of one variable against the other
fig, ax = plt.subplots(1, 1) # doctest: +SKIP
ax.scatter(foo_samples['P'], foo_samples['K'],
           marker='.', color='k', alpha=0.45) # doctest: +SKIP
ax.set_xlabel("$P$ [day]")
ax.set_ylabel("$K$ [km/s]")
# Out:
# Text(0,0.5,'$K$ [km/s]')

# %%
fig, ax = plt.subplots(1, 1) # doctest: +SKIP
ax.scatter(foo_samples['v0'], foo_samples['K'],
           marker='.', color='k', alpha=0.45) # doctest: +SKIP
ax.set_xlabel("$v_{0}$ [km/s]")
ax.set_ylabel("$K$ [km/s]")
# Out:
# Text(0,0.5,'$K$ [km/s]')

# %%
fig, ax = plt.subplots(1, 1) # doctest: +SKIP
ax.scatter(foo_samples['v0'], foo_samples['e'],
           marker='.', color='k', alpha=0.45) # doctest: +SKIP
ax.set_xlabel("$v_{0}$ [km/s]")
ax.set_ylabel("$e$ ")
# Out:
# Text(0,0.5,'$e$ ')

# %%
fig, ax = plt.subplots(1, 1) # doctest: +SKIP
ax.scatter(foo_samples['P'], foo_samples['omega'],
           marker='.', color='k', alpha=0.45) # doctest: +SKIP
ax.set_xlabel("$P$ [day]")
ax.set_ylabel("$omega$ ")
# Out:
# Text(0,0.5,'$omega$ ')

# %%
fig, ax = plt.subplots(1, 1) # doctest: +SKIP
ax.scatter(foo_samples['P'], foo_samples['e'],
           marker='.', color='k', alpha=0.45) # doctest: +SKIP
ax.set_xlabel("$P$ [day]")
ax.set_ylabel("$e$ ")
# Out:
# Text(0,0.5,'$e$ ')

# %%
fig, ax = plt.subplots(1, 1) # doctest: +SKIP
ax.scatter(foo_samples['P'], foo_samples['M0'],
           marker='.', color='k', alpha=0.45) # doctest: +SKIP
ax.set_xlabel("$P$ [day]")
ax.set_ylabel("$M0$ ")
# Out:
# Text(0,0.5,'$M0$ ')

# %%
fig, ax = plt.subplots(1, 1) # doctest: +SKIP
ax.scatter(foo_samples['P'], foo_samples['K'],
           marker='.', color='k', alpha=0.45) # doctest: +SKIP
ax.set_xlabel("$P$ [day]")
ax.set_ylabel("$K$ [km/s]")
# Out:
# Text(0,0.5,'$K$ [km/s]')
